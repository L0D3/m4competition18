# %%
import os
import numpy as np
# from __future__ import division
from matplotlib import pyplot
import pandas as pd
from pandas.plotting import autocorrelation_plot
from pandas.plotting import autocorrelation_plot

# %%
#  Yearly Resultaten
Resultats= pd.read_csv("outM4all.csv", skiprows=0, index_col =0)
Resultats
columnsname= ["model","sMape Yearly","Mase Yearly"]
ds_yearly = pd.DataFrame(columns=columnsname )
#ds.to_csv('yearly_resultat.csv')
ds_yearly.iloc[:,0]= Resultats.iloc[:,0]
ds_yearly.iloc[:,1]= Resultats.iloc[:,6]
ds_yearly.iloc[:,2]= Resultats.iloc[:,13]
ds_yearly
# Out:
#                    model  sMape Yearly  Mase Yearly
# 0       LinearRegression        0.3260      79.3850
# 1  DecisionTreeRegressor        0.3297       5.2569
# 2    KNeighborsRegressor        0.3076       4.7270
# 3                    SVR        0.3983       5.3667
# 4              MLP_Bench        0.1976       3.2508
# 5              RNN_Bench        0.1939       3.2733

# %%
#  Quaterly Resultaten
Resultats= pd.read_csv("outM4all.csv", skiprows=0, index_col =0)
Resultats
columnsname= ["model","sMape Quaterly","Mase Quaterly"]
ds_quaterly = pd.DataFrame(columns=columnsname )
#ds.to_csv('yearly_resultat.csv')
ds_quaterly.iloc[:,0]= Resultats.iloc[:,0]
ds_quaterly.iloc[:,1]= Resultats.iloc[:,5]
ds_quaterly.iloc[:,2]= Resultats.iloc[:,12]
ds_quaterly
# Out:
#                    model  sMape Yearly  Mase Yearly
# 0       LinearRegression        0.1648       1.7004
# 1  DecisionTreeRegressor        0.1236       1.5097
# 2    KNeighborsRegressor        0.1334       1.6275
# 3                    SVR        0.2731       3.5039
# 4              MLP_Bench        0.1314       1.4956
# 5              RNN_Bench        0.1303       1.6035

# %%
Resulta= pd.read_csv("outM4all.csv", skiprows=0, index_col =0)
Resulta
# Out:
#                    Model  sMape Hourly  sMape Daily  sMape Weekly  \
# 0       LinearRegression        0.3705       0.0274        0.0977
# 1  DecisionTreeRegressor        0.4435       0.0308        0.0787
# 2    KNeighborsRegressor        0.3634       0.0311        0.0901
# 3                    SVR        0.5552       0.1403        0.2441
# 4              MLP_Bench        0.0000       0.0000        0.1934
# 5              RNN_Bench        0.0000       0.0000        0.1114
#
#    sMape Monthly  sMape Quaterly  sMape Yearly  sMAPE TOTAL  Mase Hourly  \
# 0         0.0820          0.1648        0.3260       0.1781       9.6697
# 1         0.1000          0.1236        0.3297       0.1844       8.9419
# 2         0.1229          0.1334        0.3076       0.1747       6.6049
# 3         0.1195          0.2731        0.3983       0.2884      45.0352
# 4         0.1470          0.1314        0.1976       0.0000       0.0000
# ...

# %%
Resultats.iloc[:,13]
# Out:
# 0    79.3850
# 1     5.2569
# 2     4.7270
# 3     5.3667
# Name: Mase Yearly, dtype: float64

# %%
Resultats1= pd.read_csv("outputM4_20_sample.csv", skiprows=0, index_col =0)
Resultats1.T
# Out:
#                      0               1             2            3
# Data_Type  Yearly_data  Quarterly_data  Monthly_data  Weekly_data
# sMape MLP     0.197638        0.131421      0.146993     0.193492
# sMape RNN     0.193903        0.130282      0.133996     0.111373
# Mase MLP       3.25085         1.49558       2.00413       7.0898
# Mase RNN       3.27333         1.60348       1.23198      3.82459
